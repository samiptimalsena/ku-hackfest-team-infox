# %%
import speech_recognition as sr
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence

# %%
recognizer = sr.Recognizer()

# %%
def clipper(path:str, start:int, end:int, save_path=None) -> str:
    """
    Clipping the downloaded audio to provided length
    
    Args:
        path: Path of the audio
        start: starting second
        end: ending second
        save_path: path for saving the file
    
    Returns:
        Path to the clipped audio
    """
    
    sound = AudioSegment.from_wav(path)
    cropped_sound = sound[start*1000:end*1000]
    
    if save_path is None:
        save_path = "./"
    
    sound_save_path = save_path + "cropped.wav"
    
    cropped_sound.export(sound_save_path, format="wav")
    return sound_save_path

# %%
# clipper("./socheko_prapta_garne.wav", 48, 3600, "./")
# clipper("./socheko_prapta_garne.wav", 20, 80, "./")

# %%
def split_silence(path:str) -> str:
    """
    Splitting the sound on silence
    
    Args:
        path: path of the sound file
        
    Returns:
        path to the saved chunks of the splitted sound
    """
    sound = AudioSegment.from_wav(path)
    chunks = split_on_silence(sound, min_silence_len=200, silence_thresh=sound.dBFS-14, keep_silence=500)
    
    dir_name = "wavs"
    if not os.path.isdir(dir_name):
        os.mkdir(dir_name)
    
    for i, audio_chunk in enumerate(chunks):
        chunk_filename = os.path.join(dir_name, f"ku_hackfest_{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
    
    return dir_name

# %%
def clip_and_save_on_silence(path:str, start:int, end:int, clip_save_path=None):
    """
    Clipping and saving on silence
    
    Args:
        path: Path of the audio
        start: starting second
        end: ending second
        clip_save_path: path for saving the file
        
    Returns:
        path to the saved chunks of the splitted sound
    """
    
    cropped_path = clipper(path, start, end, clip_save_path)
    dir_name = split_silence(cropped_path)
    return dir_name

# %%
clip_and_save_on_silence('./socheko_prapta_garne.wav', 48, 3600, "./")
# Out:
# 'wavs'

# %%
def get_num(filename):
    split_on_under = filename.split("\t")[0].split("_")
    comb = split_on_under[-2] + split_on_under[-1]
    zero_cnt = 4 - len(comb)
    numeric = int(split_on_under[-2] + "0"*zero_cnt + split_on_under[-1])
    return numeric

# %%
get_num('ku_hackfest_part_3_345	2013 आफ्नो विश्वासिलो शान्त छ',)
# Out:
# 3345

# %%
with open("part3.txt") as f:
    lines = f.readlines()
    lines = sorted(lines, key=lambda x: get_num(x))

# %%
lines
# Out:
# ['ku_hackfest_part_3_0\tमैले तार्किक मन्त्रीस्तरमा विचार गर्नु हुन्छ तपाईंको नियमित विचार\n',
#  'ku_hackfest_part_3_1\tअवचेतन मनमा गहिरिएर बसेको हुन्छ\n',
#  'ku_hackfest_part_3_2\tVcb क्षणको अनुरुप यथार्थ सिर्जना गर्दछ\n',
#  'ku_hackfest_part_3_3\tअवचेतन मन उत्तेजना र भावको थलो हो\n',
#  'ku_hackfest_part_3_5\t32 सिर्जनशील हुन्छ\n',
#  'ku_hackfest_part_3_6\tभइलि सकारात्मक सोच्नुहुन्छ भने परीणाम सकारात्मक हुन्छ\n',
#  'ku_hackfest_part_3_7\tनकारात्मक सोचले\n',
#  'ku_hackfest_part_3_8\tनकारात्मक परिणीति सिर्जना गर्दछ\n',
#  'ku_hackfest_part_3_9\tमनले rational विधिबाट काम गर्छ\n',
#  'ku_hackfest_part_3_10\tयाद राख्ने पर्ने कुरा के हो भने\n',
#  'ku_hackfest_part_3_11\tअवचेतन मनले कुनैपनि भिसालाई स्वीकार गर्छ\n',
#  'ku_hackfest_part_3_12\tजसले subhi साथै\n',
#  'ku_hackfest_part_3_13\tधारण गर्न थाल्छ\n',
#  'ku_hackfest_part_3_14\tUtaru चिकनी सुसन सत्य नै हो\n',
#  'ku_hackfest_part_3_15\tआवश्यक हुन् उनले सरकार makra नकाट्न बेसारमा\n',
#  'ku_hackfest_part_3_16\tभेदभाव नगरी\n',
#  'ku_hackfest_part_3_17\tसम्मान प्रतिक्रिया जनाउँछ\n',
#  'ku_hackfest_part_3_18\tDinraat na bichhad जब unin लागू हुन्छ\n',
#  'ku_hackfest_part_3_19\tIs lil असफलता अन्योल र दुख जन्माउछ\n',
#  'ku_hackfest_part_3_20\tBest विपरित जब विचार आनन्ददायक rosna हुन्छ\n',
#  'ku_hackfest_part_3_21\tअहिले राम्रो स्वास्थ्य is सफलता\n',
#  'ku_hackfest_part_3_22\tसम्पूर्णता हासन गर्न सक्नुहुन्छ यदि सकारात्मक सोच विचार गर्दा tishna भावशून्य गर्नुभयो भने\n',
#  'ku_hackfest_part_3_23\tशारीरिक र मानसिक स्वास्थ्य तपाईंको अभिन्न अङ्ग भन्छ\n',
#  'ku_hackfest_part_3_24\tअहिले मनमा अडान jica\n',
#  'ku_hackfest_part_3_25\tजेथा जमानी का हरेक कुरालाई\n',
#  'ku_hackfest_part_3_26\tभएको हो\n',
#  'ku_hackfest_part_3_27\tअवचेतन मनले स्वीकार गर्छ\n',
#  'ku_hackfest_part_3_28\tतपाईंको अनुभवमा जोड्दछ\n',
#  'ku_hackfest_part_3_29\tमात्र तपाईंले आफ्नो विचारलाई\n',
#  'ku_hackfest_part_3_30\tअवचेतन मनको स्तरमा स्वीकृत\n',
#  'ku_hackfest_part_3_31\tनमान्ने बनाउनुपर्छ\n',
#  'ku_hackfest_part_3_32\tत्यसपछि अवश्य तनमन को वास्तविक स्वभावले\n',
#  'ku_hackfest_part_3_33\tअहिले चाहनुभएको स्वास्थ्य सकते wap\n',
#  'ku_hackfest_part_3_34\tप्रतिष्ठाको प्राप्ति सम्भव बनाउँछ\n',
#  'ku_hackfest_part_3_35\tJuicy तपाईले यस्तो stars दिनुहुन्छ\n',
#  'ku_hackfest_part_3_36\tभएको हुनले\n',
#  'ku_hackfest_part_3_37\tरिसलाई यथार्थ हुने प्रतिक्रियात्मक प्रज्ञा शुरु गर्दछ\n',
#  'ku_hackfest_part_3_38\tभएको क्षेत्र मनले मान्यता दिएको विचारहरू\n',
#  'ku_hackfest_part_3_39\tअवस्थित हुन् उनले प्रतिक्रिया दिन्छ\n',
#  'ku_hackfest_part_3_40\tमनोविज्ञान र मनुष्य कृषकका अनुसार अवचेतन मनमा सन्देश वा संकेत होला हुँदा मस्तिष्कको कोषमा अंकित हुन्छ छाप पर्छ\n',
#  'ku_hackfest_part_3_41\tअवचेतन मनले कुनैपनि bessan स्वीकार गर्ने बित्तिकै\n',
#  'ku_hackfest_part_3_42\tयसलाई प्रभावकारी बनाउने काम सुरु गरिहाल्छ\n',
#  'ku_hackfest_part_3_43\tयसले पुरानो अनुभव र सम्बन्धित घटनाबाट संकलित सम्पूर्ण ज्ञान\n',
#  'ku_hackfest_part_3_44\tकार्यमा पूर्णताका साथ लगानी गर्दछ\n',
#  'ku_hackfest_part_3_45\tएसले तपाई भित्र कन शक्ति ऊर्जा र ज्ञान हुँदा गर्दछ\n',
#  'ku_hackfest_part_3_46\tAsli कार्य पूरा गर्न प्रकृतिका सम्पुर्ण नियमलाई\n',
#  'ku_hackfest_part_3_47\tआफ्नो हितमा प्रयोग गर्छ\n',
#  'ku_hackfest_part_3_48\tअहिलेकै तपाईंको समस्यामा तत्काल समाधान भएपनि\n',
#  'ku_hackfest_part_3_49\tकतिपय अवस्थामा केही दिन\n',
#  'ku_hackfest_part_3_50\tहप्ता\n',
#  'ku_hackfest_part_3_51\tत्यो भन्दा लामो सुनिएपनि लाग्नसक्छ\n',
#  'ku_hackfest_part_3_52\tकति छिटो समाधान हुन्छ भन्ने कुरा तपाईंका विगतका क्रियाकलापहरुमा\n',
#  'ku_hackfest_part_3_53\tभर पर्दछ\n',
#  'ku_hackfest_part_3_54\tक्षेत्रगत anvesh\n',
#  'ku_hackfest_part_3_55\tभिन्नता\n',
#  'ku_hackfest_part_3_56\tभन्ने बुझ्नुपर्छ कि\n',
#  'ku_hackfest_part_3_57\tदुई खुट्टा सुत्ने मस्तिष्क भइनन्\n',
#  'ku_hackfest_part_3_58\tTuekey मस्तिष्कका 2din कार्यक्षेत्रका कार्यव्यवस्था मात्र\n',
#  'ku_hackfest_part_3_59\tChitwan park menu\n',
#  'ku_hackfest_part_3_60\tमनको त्यो अवस्था जसले छनौट दरमा सक्छ चुनाब गर्न सक्छ\n',
#  'ku_hackfest_part_3_61\tउदाहरणका लागि तपाईं आफूले पढ्ने पुस्तक\n',
#  'ku_hackfest_part_3_62\tआफ्नो लागि घर या जीवन साथी संगत गर्नुहुन्छ\n',
#  'ku_hackfest_part_3_63\tमिसन पूर्ण क्षति मन्दिर गर्दछ\n',
#  'ku_hackfest_part_3_64\tअर्कातिर कुनै सचित्र योजनाबिना तपाईंको मुटु धडके रनछ\n',
#  'ku_hackfest_part_3_65\tभाषणकला रक्तसञ्चार पनि स्वासप्रस्वास चलिरहन्छ\n',
#  'ku_hackfest_part_3_66\tकार्यक्षेत्र मनको नियन्त्रण नानी अवचेतन मनले सम्पुर्ण गर्दछ\n',
#  'ku_hackfest_part_3_67\tभएको क्षेत्र मन्दिर सही मान्ने\n',
#  'ku_hackfest_part_3_68\tअवचेतन मनमा सञ्चार गर्ने कुनै पनि कुरा\n',
#  'ku_hackfest_part_3_69\tअवचेतन मनले\n',
#  'ku_hackfest_part_3_70\tEcard छ\n',
#  'ku_hackfest_part_3_71\tविश्वास गर्दछ यसले चेतनले जस्तो\n',
#  'ku_hackfest_part_3_72\tउनको गर्दैन\n',
#  'ku_hackfest_part_3_73\tनदिएको तथ्यमा कुनै विभाग पनि गर्दैन\n',
#  'ku_hackfest_part_3_74\tभएको भए तनमन tyohar होमियो\n',
#  'ku_hackfest_part_3_75\tजसमा असो या खराब 2tb उम्रन सक्छ विषालु विश्वास निमन काव्य हुन्\n',
#  'ku_hackfest_part_3_76\tLakha pukra insan विचारहरु निरन्तर नकारात्मक रुपमा\n',
#  'ku_hackfest_part_3_77\tकार्यकरम song\n',
#  'ku_hackfest_part_3_78\tRookie सुनेपछि 30e अनुरुपका गत maro परिस्थिति बनेर देखापर्छ\n',
#  'ku_hackfest_part_3_79\tNeet\n',
#  'ku_hackfest_part_3_80\tअवचेतन मनले पहिले नै एक घटना र परिस्थितिको अनुभव गरिसकेको हुन्छ\n',
#  'ku_hackfest_part_3_81\tअवश्य तनमनले तपाईंका मनका sanchai\n',
#  'ku_hackfest_part_3_82\tराम्रा वा नराम्रा\n',
#  'ku_hackfest_part_3_83\tप्रतिभा झुठा हुन् भन्ने कुरा\n',
#  'ku_hackfest_part_3_84\tप्रमाणित नगरी तपाईंको विचार वा सुझावको प्रकृतिअनुसार प्रतिक्रिया दिन्छ\n',
#  'ku_hackfest_part_3_85\tउदाहरणको लागि\n',
#  'ku_hackfest_part_3_86\tयदि कुनै कुरा गलत भए तपाईंले त्यसलाई सचेत रूपमा a मान्नु भएपनि\n',
#  'ku_hackfest_part_3_87\tभएको हो सही मंडी यसलाई सत्य कुराको रुपमा स्वीकार गर्नेछ प्रेसलाई\n',
#  'ku_hackfest_part_3_88\tहोइन निकाल्ने desha म अगाडी बढाउछ\n',
#  'ku_hackfest_part_3_89\tजसलाई तपाईंले अनुसरण गर्नुपर्दछ\n',
#  'ku_hackfest_part_3_90\tभनेक सचित्र तपाईंले यसलाई सत्य पनि मान्नु\n',
#  'ku_hackfest_part_3_92\tमनोविज्ञहरु को प्रयोग\n',
#  'ku_hackfest_part_3_93\tमनोविज्ञान हुने अनुसन्धानकर्ताको द्वारा सम्मोहित अवस्थाका bacter मन गरिएका\n',
#  'ku_hackfest_part_3_94\tअसंख्य प्रेममा के देखिएको सपना\n',
#  'ku_hackfest_part_3_95\tअवस्य सुमनसँग गर्न महत्वपूर्ण गर्न असक्षम छ\n',
#  'ku_hackfest_part_3_96\tभेगमा अवचेतन मनमा sunsari सुझाव jatini जतुवा आधारहीन भएमा पनि\n',
#  'ku_hackfest_part_3_97\tघार गर्छन् भन्ने निष्कर्ष निस्केको छ\n',
#  'ku_hackfest_part_3_98\tकुनै सुझाव स्वीकार गरिसकेपछि अब सूत मनले 30in अनुरुपको परिस्थिति सिर्जना गर्न थाल्नुहुन्छ\n',
#  'ku_hackfest_part_3_99\tSunsari सुझावमाथि अवस्थित अहम्को स्वीकारोक्ति हेर्दा यदि एउटा दक्षिणसम्म कर्ताले एउटा समृद्धिलाई\n',
#  'ku_hackfest_part_3_100\tनेपोलियन बोनापार्ट भएको\n',
#  'ku_hackfest_part_3_101\tकुकुर विरालो भएको सुझाव दिन्छ भने\n',
#  'ku_hackfest_part_3_102\tउसले सो सुझाव अनुरोध\n',
#  'ku_hackfest_part_3_103\tNicole in वा कुकुर विरालो जस्तो विभाग\n',
#  'ku_hackfest_part_3_104\tक्षमता देखाउँछ निश्चित अवधिको लागि उसको व्यवहार र क्षमता परिवर्तन हुन्छ\n',
#  'ku_hackfest_part_3_105\tसम्मोहित व्यक्तिमा आफूलाई समूह कथाले जे भन्छ त्यही हो भन्नेमा पुर्ण विश्वास हुन्छ एक दक्ष समूह कर्ताले समूह\n',
#  'ku_hackfest_part_3_106\tअवस्थाका व्यक्ति मध्ये एकलाई\n',
#  'ku_hackfest_part_3_107\tधर्तीलाई राखेको\n',
#  'ku_hackfest_part_3_108\tअर्को नाकबाट रगत आएको\n',
#  'ku_hackfest_part_3_109\tKolai ho मूर्ति भएको रहरको laijare उल्लेख गरिएको सुझाव दिनसक्छ\n',
#  'ku_hackfest_part_3_110\tहरेक व्यक्तिले भाग हुन् व्यक्तिगत विचारमा ट\n',
#  'ku_hackfest_part_3_111\tVianet\n',
#  'ku_hackfest_part_3_112\tआफ्नो सीमा नाघ्दै\n',
#  'ku_hackfest_part_3_113\tAmul कर्ताले दिएको आदेश जस्तै\n',
#  'ku_hackfest_part_3_114\tसम्मोहित ले आसुँ देखाउँछ\n',
#  'ku_hackfest_part_3_115\tउदाहरणबाट क्षेत्र बस्तु मनको कार्यसम्पादन स्पष्ट हुनजान्छ अवचेतन मन व्यक्तिभन्दा माथि रहेका क्षेत्र मनले प्रवाहित गर्ने\n',
#  'ku_hackfest_part_3_116\tहरेक सुझावलाई विश्वास गर्छ\n',
#  'ku_hackfest_part_3_117\tप्रश्नः तपाईलाई उपचार गर्ने प्रेरणा दिने\n',
#  'ku_hackfest_part_3_118\tआनन्दित बनाउने विचारहरू\n',
#  'ku_hackfest_part_3_119\tRoot गर्ने सन्दर्भमा\n',
#  'ku_hackfest_part_3_120\tBishal\n',
#  'ku_hackfest_part_3_121\tNikki महत्वपूर्ण हुन्छन्\n',
#  'ku_hackfest_part_3_122\tव्यक्ति फरक र वस्तुपरक mankar\n',
#  'ku_hackfest_part_3_123\tभएको क्षेत्र मन्दिर वस्तुपरक क्षेत्र namen जनाउँछ\n',
#  'ku_hackfest_part_3_124\tकि यसले बाहिरी वस्तु सँग सम्बन्धित रहेर कार्य गर्दछ\n',
#  'ku_hackfest_part_3_125\tChitra mandir भौतिक संसारको ज्ञान लाग्दछ\n',
#  'ku_hackfest_part_3_126\t5 ज्ञानेन्द्रिय हरु\n',
#  'ku_hackfest_part_3_127\tयसको अनुभव र कनका\n',
#  'ku_hackfest_part_3_128\tमाध्यम\n',
#  'ku_hackfest_part_3_129\tChitwanma liveyes duniya सङ्घको सम्बन्धमा\n',
#  'ku_hackfest_part_3_130\tमार्ग निर्देशकको भूमिका निर्वाह गर्दछ\n',
#  'ku_hackfest_part_3_131\tवस्तुपरक मनले अवलोकन अनुभव रहनका आधारमा ज्ञान हासिल गर्दछ\n',
#  'ku_hackfest_part_3_132\tपूर्व हुनेगरी अनुरुप क्षेत्र मनको कार्य\n',
#  'ku_hackfest_part_3_133\tकर्कश एउटा हो\n',
#  'ku_hackfest_part_3_134\tमानौं तपाईं लसएन्जलस घुम्न जाने\n',
#  'ku_hackfest_part_3_135\tहजारौं पर्यटक मध्येको एक हुनुहुन्छ\n',
#  'ku_hackfest_part_3_136\tSkypark सुन्दर बगैंचा\n',
#  'ku_hackfest_part_3_137\tभव्य महल\n',
#  'ku_hackfest_part_3_138\tसुन्दर भवनहरूको अवलोकन गरेर\n',
#  'ku_hackfest_part_3_139\tयो निष्कर्षमा पुग्नुहुन्छ ke\n',
#  'ku_hackfest_part_3_140\tघर सुन्दर छ\n',
#  'ku_hackfest_part_3_141\tSaiko वस्तुपरक मनको कार्यप्रणाली\n',
#  'ku_hackfest_part_3_143\tअवचेतन मनलाई ब्याक्ती pockmon पनि भनिन्छ\n',
#  'ku_hackfest_part_3_144\tअवचेतन मनले पाँच ज्ञानेन्द्रिय संग सम्बन्धित नभई\n',
#  'ku_hackfest_part_3_145\tज्ञान ashru पक्ष\n',
#  'ku_hackfest_part_3_146\tअवचेतन मनले अन्तर्गतको माध्यमबाट ज्ञान हासिल गर्छ\n',
#  'ku_hackfest_part_3_147\tभावको rista हो भने यस नीतिको भन्दापनि\n',
#  'ku_hackfest_part_3_148\tअवचेतन मनले सबैभन्दा प्रभावकारी रुपमा कार्य गर्दछ\n',
#  'ku_hackfest_part_3_149\tचेतन मन\n',
#  'ku_hackfest_part_3_150\tयस्तो शक्ति हो\n',
#  'ku_hackfest_part_3_151\tजुन निद्रामा हुँदा वा निष्क्रिय हुँदा\n',
#  'ku_hackfest_part_3_152\tआफूलाई अझ सक्रिय गर्दछ\n',
#  'ku_hackfest_part_3_153\tअवचेतन मन्दिर शरीर भौतिक केन्द्रमार्फत नभई\n',
#  'ku_hackfest_part_3_154\tParkiti केन्द्रमा सोच्दछु\n',
#  'ku_hackfest_part_3_155\tभीष्म अन्तरदृष्टि lantha सोतीको क्षमता हुन्छ\n',
#  'ku_hackfest_part_3_156\tअवचेतन मन तपाईंको शरीर छोडेर\n',
#  'ku_hackfest_part_3_157\tहजारौं किलोमिटर दूरी यात्रा गरी\n',
#  'ku_hackfest_part_3_158\tOnlinesic निश्चित तथ्य पत्ता लगाउन सक्छ\n',
#  'ku_hackfest_part_3_159\tब्याक्ती permko प्रयोगले तपाईले हरुकाे विशाखा पाउन सकिन्छ\n',
#  'ku_hackfest_part_3_160\tबन्द खामभित्र cobin उत्पन्न सक्नुहुन्छ बन्द saveit हेर्न सक्नुहुन्छ\n',
#  'ku_hackfest_part_3_161\tभारतमा भक्तिको वा\n',
#  'ku_hackfest_part_3_162\tAbhisha cocala बोल्न क्षेत्र बसु मनको\n',
#  'ku_hackfest_part_3_163\tUncle kyabord\n',
#  'ku_hackfest_part_3_164\tअत्यावश्यक\n',
#  'ku_hackfest_part_3_165\tअवश्य तनमनले क्षेत्र मनले जस्तो\n',
#  'ku_hackfest_part_3_166\tछल गर्न सक्दैन\n',
#  'ku_hackfest_part_3_167\tभएको अबचेतन मनले विभाग गर्न सक्दैन\n',
#  'ku_hackfest_part_3_168\tनिष्काशन तपाईंले गर्न सुझाव दिनुभएको नि\n',
#  'ku_hackfest_part_3_169\tअबस्य चुम्ने स्वीकार गर्दछ\n',
#  'ku_hackfest_part_3_170\tती सुझावलाई परिस्थिति अनुभव dhatako रुपमा\n',
#  'ku_hackfest_part_3_171\tसम्प्रेषण गर्दछ\n',
#  'ku_hackfest_part_3_172\tघटिका हरेक घटना रोगीका or\n',
#  'ku_hackfest_part_3_173\tपरिस्थितिहरु तपाईंको अवश्यक namma\n',
#  'ku_hackfest_part_3_174\tभीष्म सहित सञ्चार\n',
#  'ku_hackfest_part_3_175\tप्रतिफल हो यदि तपाईंले धेरै गलत र नकारात्मक सन्देश प्रवाहित गर्नुभएको छ भने पृष्ठ सन्देशका आसनबाट बस्ने\n',
#  'ku_hackfest_part_3_176\tयतिमात्र पाेषण\n',
#  'ku_hackfest_part_3_177\tMovie साडी एवं विश्वासको नौलो प्रणाली सृजना गर्ने गरी बारम्बार सकारात्मक र प्रगतिशील भाव ल्याउने\n',
#  'ku_hackfest_part_3_178\tUpaya\n',
#  'ku_hackfest_part_3_179\tभनी अवश्य taman तपाईंको nemish school pratibimba\n',
#  'ku_hackfest_part_3_180\tचेतन मन को नियमित विचार प्रणालीले अवचेतन मनमा\n',
#  'ku_hackfest_part_3_181\tगहिरो प्रभाव पारेको हुन्छ\n',
#  'ku_hackfest_part_3_182\tबैंक\n',
#  'ku_hackfest_part_3_183\tनियमित सुन्दैछु सरसर प्रगतिशील रचनात्मक र शान्त छन भने\n',
#  'ku_hackfest_part_3_184\tयुद्ध थी तपाईंका लागि\n',
#  'ku_hackfest_part_3_185\tव्यक्तिहरूको हुनसक्छ\n',
#  'ku_hackfest_part_3_186\tतपाईंले\n',
#  'ku_hackfest_part_3_187\tआफूले भयो त्रास चिन्ता तनाव नेर्पा बढाउनुभएको छ भनी\n',
#  'ku_hackfest_part_3_188\tयसको उपचार अवचेतन मनको शक्तिको पहिचान गरी प्रफुल्लता\n',
#  'ku_hackfest_part_3_189\tस्वास्थ्य सिर्जनशीलता प्राप्त गर्नु\n',
#  'ku_hackfest_part_3_190\tअवचेतन मन आफैमा सिर्जनशील र दिव्यश्वर सँग\n',
#  'ku_hackfest_part_3_191\tएकाकार भएकोले तपाईंले गम्भीरताका साथ सानो भएको मुक्ति ramra का लागि\n',
#  'ku_hackfest_part_3_192\tप्रक्रिया\n',
#  'ku_hackfest_part_3_193\tअघि बढाउँछ\n',
#  'ku_hackfest_part_3_194\tसुझावको अदभुत शक्ति\n',
#  'ku_hackfest_part_3_195\tअहिलेसम्म तपाईले महसुस गर्नुभएको छ\n',
#  'ku_hackfest_part_3_196\tचेतन मन\n',
#  'ku_hackfest_part_3_197\tगीतको पाले जस्तै\n',
#  'ku_hackfest_part_3_198\tजसको महत्वपूर्ण कार्य\n',
#  'ku_hackfest_part_3_199\tअवचेतन मनमा पुग्न खोज्ने नका प्रभावको प्रभावलाई\n',
#  'ku_hackfest_part_3_200\tनिस्के झार्नु\n',
#  'ku_hackfest_part_3_201\tभूत पनि उनको आधारभूत कार्यप्रणाली संग परिचित हुनुभएको छ उचित हुनुलाई सुझावले\n',
#  'ku_hackfest_part_3_202\tअधिक प्रभावित भान्सा अवचेतन मनले तर्क विभाग तुलना गर्दैन रहित वा अहित निजाम\n',
#  'ku_hackfest_part_3_203\tएकाइहरू क्षेत्र मनको क्षेत्रभित्र पर्दछन्\n',
#  'ku_hackfest_part_3_204\tअवस्थी manlea केबुल चेतन मनले पठाएका सूचना चुनावको प्रतिक्रिया देखाउँछ\n',
#  'ku_hackfest_part_3_205\tBitly एक वा अर्को कार्यालय प्राथमिकता दिँदै\n',
#  'ku_hackfest_part_3_206\tवस्तु धारण आत्म सुझावको विराट शक्तीको bristol आरण हो\n',
#  'ku_hackfest_part_3_207\tअहिले जहाजै यात्रुमध्ये संकुचित 1 यात्रीलाई\n',
#  'ku_hackfest_part_3_208\tTusu देखिनुहुन्छ\n',
#  'ku_hackfest_part_3_209\tअनुहार पाउनुभएको छ\n',
#  'ku_hackfest_part_3_210\tमक्का सुखी तपाईं बिरामी हुन्छ\n',
#  'ku_hackfest_part_3_211\tमैले cabin सामु पुर्याउनु\n',
#  'ku_hackfest_part_3_212\tभन्नुभए पनि उसको अनुहारको रङ्ग शास्त्र तपाईलाई toon swostika सकिने कि तपाईंका शब्दहरुले उसमा पहिलेदेखि भएको दललाई पुर्णरुपमा खुलाउँछ\n',
#  'ku_hackfest_part_3_213\tअहिले हो भन्ने ठाउँसम्म पुर्याउँदा\n',
#  'ku_hackfest_part_3_215\tबिरामी भइसकेको हुन्छ\n',
#  'ku_hackfest_part_3_216\tहुती सुझावप्रति को फरक प्रतिक्रिया कुनैपनि व्यक्तिको kumawat hamko asthm आवश्यकताअनुसार\n',
#  'ku_hackfest_part_3_217\tएउटी सुझावप्रति पनि दुई व्यक्ति भिन्न मत\n',
#  'ku_hackfest_part_3_218\tया प्रतिक्रिया\n',
#  'ku_hackfest_part_3_219\tउदाहरणको लागि तपाईले सहानुभूतिका साथ हो जहाँ चालकलाई\n',
#  'ku_hackfest_part_3_220\tभित्र\n',
#  'ku_hackfest_part_3_221\tफेसन सस्तो देखिनुहुन्छ\n',
#  'ku_hackfest_part_3_222\tगारो भएको छैन\n',
#  'ku_hackfest_part_3_223\tभन्नुभयो भने\n',
#  'ku_hackfest_part_3_224\tउसको स्वभाव अनुसार उक्त भाइको ठट्टामा आशावादी सताउन सक्छ\n',
#  'ku_hackfest_part_3_225\tभएका सबैलाई सुनाएँ झैं प्रभावहीन हुन्छ\n',
#  'ku_hackfest_part_3_226\tकिनकी उसको अनुभव विश्वासले\n',
#  'ku_hackfest_part_3_227\tती कुरा स्वीकार गर्न सक्दैन\n',
#  'ku_hackfest_part_3_228\tPrashansa तपाइँको बोलीले उष्ण भएता सिर्जना गरी आत्मविश्वास बढाउँछ\n',
#  'ku_hackfest_part_3_229\tअंग्रेजी शब्दकोशका अनुसारको sickman न कुनै विशाल पठाउनु सुझाव\n',
#  'ku_hackfest_part_3_230\tVersion\n',
#  'ku_hackfest_part_3_231\tYou\n',
#  'ku_hackfest_part_3_232\tयस्तो मानसिक प्रक्रिया हो\n',
#  'ku_hackfest_part_3_233\tजसमा दिएको bicha स्वीकार गरिन्छ\n',
#  'ku_hackfest_part_3_234\tकार्यमा चाहिन्छ\n',
#  'ku_hackfest_part_3_235\tअहिले याद राख्नुपर्ने कुरा\n',
#  'ku_hackfest_part_3_236\tचुम्बनको अनुमतिबिना कुनै पनि सुझावले अवचेतन मनमा प्रभाव पार्न सक्दैन\n',
#  'ku_hackfest_part_3_237\tअर्को शब्दमा भन्नुपर्दा चेतन मनमा बाहिर सुझावलाई अस्वीकार गर्न सक्ने शक्ति हुन्छ\n',
#  'ku_hackfest_part_3_238\tविशालको सवालमा उसलाई बिरामीको कुनै दर्ता थिएन\n',
#  'ku_hackfest_part_3_239\tउसलाई आफ्नो प्रतिरोध शक्तिमा पूर्ण विश्वास\n',
#  'ku_hackfest_part_3_241\tती सुझावले उसमा जल उत्पन्न गर्नसक्ने\n',
#  'ku_hackfest_part_3_242\tउनीहरुले दिएको 30t सुलभले उमेरमा कथा कथा लुकेको भएमा जलाइदिए\n',
#  'ku_hackfest_part_3_243\tहामीहरु हरेक नभए विश्वास अनि\n',
#  'ku_hackfest_part_3_244\tभिसाको निश्चित प्रणाली अन्तर्निहित छ\n',
#  'ku_hackfest_part_3_245\tजसले हाम्रो सम्पूर्ण जीवन\n',
#  'ku_hackfest_part_3_246\tसञ्चालन गरिरहेको छ\n',
#  'ku_hackfest_part_3_247\tर म तवसम्म कुनै शक्ति वा प्रभाव हुँदैन\n',
#  'ku_hackfest_part_3_248\tजबसम्म तपाईंले मानसिक रुपमा स्वीकार गर्नु\n',
#  'ku_hackfest_part_3_249\tयसकारण पनि तपाईंले स्वीकार गर्ने सुझावको प्रकृतिअनुरूप ko\n',
#  'ku_hackfest_part_3_250\tनियन्त्रित र विशिष्ट घेरामा\n',
#  'ku_hackfest_part_3_251\tअवस्थित ham\n',
#  'ku_hackfest_part_3_252\tकार्यरत हुन्छ\n',
#  'ku_hackfest_part_3_255\tBasuri उनले हात गुमाए\n',
#  'ku_hackfest_part_3_256\tहरेक 203 वर्षमा\n',
#  'ku_hackfest_part_3_257\tम लण्डनको thumko\n',
#  'ku_hackfest_part_3_258\tGhak song ham आप्रवासन दिने गर्थे\n',
#  'ku_hackfest_part_3_259\tFrom hilly केही वर्षअघि स्थापना गरेको थियो\n',
#  'ku_hackfest_part_3_260\tनिर्दिष्ट\n',
#  'ku_hackfest_part_3_261\tDoctor\n',
#  'ku_hackfest_part_3_262\tBilop li malai\n',
#  'ku_hackfest_part_3_263\tXx दोहोरी खबार morang\n',
#  'ku_hackfest_part_3_264\tजुन एक अंग्रेजी पत्रिकामा प्रकाशित\n',
#  'ku_hackfest_part_3_266\tसुझावको शक्तिमा प्रकाश पार्ने रोशु प्रसंगमा आधारित\n',
#  'ku_hackfest_part_3_267\tMcleak हिँड्दै वर्षसम्म यस्तो सुझाव तयार रहेका\n',
#  'ku_hackfest_part_3_268\tमिलिजुली निको भएमा\n',
#  'ku_hackfest_part_3_269\tमेरो दायाँ हात बढाउँदै\n',
#  'ku_hackfest_part_3_270\tहुन् किशोरी भाग\n',
#  'ku_hackfest_part_3_271\tनिकै नहुने छालहरु बाट पिडित\n',
#  'ku_hackfest_part_3_272\tमेडिकल उपचार उनको त्यो अवस्थामा सुधार ल्याउन सक्छन्\n',
#  'ku_hackfest_part_3_273\tबुबालाई भने छोडी सुस्त भएको देख्ने ठूलो इच्छा थियो प्रत्येक प्रकट गर्ने क्रममा उल्लेखित भनाइ\n',
#  'ku_hackfest_part_3_274\tDuniya dong\n',
#  'ku_hackfest_part_3_275\tBlingcom अनुसार परिवार kuni आक्रमणका\n',
#  'ku_hackfest_part_3_276\tउनीहरूको car\n',
#  'ku_hackfest_part_3_277\tKoka song जोडिनु दुर्घटनामा परि\n',
#  'ku_hackfest_part_3_278\tभूभागको दैनि हातका चुरो कामबाट छुट्टी\n',
#  'ku_hackfest_part_3_279\tत्यतिबेला छोडेको vastu\n',
#  'ku_hackfest_part_3_280\tछालहरु\n',
#  'ku_hackfest_part_3_281\tNirmal bhai\n',
#  'ku_hackfest_part_3_282\tपहिले के कुरामा ध्यान राख्नुपर्छ भने\n',
#  'ku_hackfest_part_3_283\tभएको अवस्थित मनमा प्रवाहित हुने सुझाव\n',
#  'ku_hackfest_part_3_284\tभएको जीवनका हरेक\n',
#  'ku_hackfest_part_3_285\tपरिस्थितिमा\n',
#  'ku_hackfest_part_3_286\tस्वास्थ्य\n',
#  'ku_hackfest_part_3_287\tआनन्दित र सिर्जनशील बन्ने प्रेरणा\n',
#  'ku_hackfest_part_3_289\tऊर्जा प्रदान\n',
#  'ku_hackfest_part_3_290\tगरी नहोस्\n',
#  'ku_hackfest_part_3_291\tAankhose\n',
#  'ku_hackfest_part_3_292\tभएको हो सुमनले कुरालाई ठट्टाको रुपमा लिइँदैन यसले तपाइका हरेक सचेत विचारलाई\n',
#  'ku_hackfest_part_3_293\tसत्य मान्छन्\n',
#  'ku_hackfest_part_3_295\tघर्षण अनि आफ्नो सुझावले doll बनाउँछ रातो सुझावको प्रयोग\n',
#  'ku_hackfest_part_3_296\tअात्म सुझाव आफूले दिने\n',
#  'ku_hackfest_part_3_297\tनिर्दिष्ट निश्चित सुझाव\n',
#  'ku_hackfest_part_3_298\tHawara parkins उनले आफ्नो सुझाव सम्बन्धित प्रसिद्ध कृति\n',
#  'ku_hackfest_part_3_299\tUtho jisma विवरण उल्लेख गरेका\n',
#  'ku_hackfest_part_3_300\tYou\n',
#  'ku_hackfest_part_3_301\tYeti हुन्छ कि हरेकले आ राख्नुहुन्छ\n',
#  'ku_hackfest_part_3_302\tसिकाको आजकल new निवासी ले आफ्नो गरिन यस\n',
#  'ku_hackfest_part_3_303\tजुन सिकागोको भन्दा\n',
#  'ku_hackfest_part_3_304\tकण्ठ छिटो हुन्छ chicago ka maithlai\n',
#  'ku_hackfest_part_3_305\tBharawa जिसकी sabunse\n',
#  'ku_hackfest_part_3_306\tशिखर निवासी netali nukra chicago विषको एक घण्टा समय अन्तर होस् नगरी मान्छन कि\n',
#  'ku_hackfest_part_3_307\tउनको खाना खाने बेला भयो\n',
#  'ku_hackfest_part_3_308\tउसलाई साह्रै भोक लागिसकेको छ\n',
#  'ku_hackfest_part_3_309\tरङको लागि जानुपर्यो भन्छन्\n',
#  'ku_hackfest_part_3_310\tवास्तविक समय 11 बजेको\n',
#  'ku_hackfest_part_3_311\tर उनी अरू बेला खाने हुँदा\n',
#  'ku_hackfest_part_3_312\tएक घण्टा अघि नै पकाउँछु\n',
#  'ku_hackfest_part_3_313\tआत्म सुझावमा मनुष्य क्लास निर्मूल पार्न नकारात्मक प्रभावबाट बस्न प्रेरित गर्न सकिन्छ\n',
#  'ku_hackfest_part_3_314\tZenith r1 प्रतिभाशाली युवा गायिका\n',
#  'ku_hackfest_part_3_315\tहुँदैछन् का लागि गाउँनु बोलाइएको थियो\n',
#  'ku_hackfest_part_3_316\tउनी अन्तर्वार्ताको प्रत्येक्ष माथि\n',
#  'ku_hackfest_part_3_317\tहामीसँग smbandha अघि तिनका प्रयासमा\n',
#  'ku_hackfest_part_3_318\tHashu पुर्खाको भयले गर्दा\n',
#  'ku_hackfest_part_3_319\tअसक्षम भएको अनुभव duawa\n',
#  'ku_hackfest_part_3_320\tThis month\n',
#  'ku_hackfest_part_3_321\tउनी\n',
#  'ku_hackfest_part_3_322\tआफै भन्ने गर्थे\n',
#  'ku_hackfest_part_3_323\tभाइ मैले गाएको उनीहरुलाई\n',
#  'ku_hackfest_part_3_324\tमन पर्दैन\n',
#  'ku_hackfest_part_3_325\tRemo प्रयास गर्छु\n',
#  'ku_hackfest_part_3_326\tAhw अहिले मलाई सुकी much चिन्तित र विचलित vaisaki अक्षत मन्दिर कति भाबलाई आजको\n',
#  'ku_hackfest_part_3_327\tअंगिकार गरि\n',
#  'ku_hackfest_part_3_328\tविभागलाई यथार्थ रोक्दैन र उनको अनुभवलाई ल्याउन\n',
#  'ku_hackfest_part_3_329\tप्रक्रिया सुरु गरे\n',
#  'ku_hackfest_part_3_330\tOic\n',
#  'ku_hackfest_part_3_331\tछाली\n',
#  'ku_hackfest_part_3_332\tआफ्नो सुझावका कारण भएको थियो\n',
#  'ku_hackfest_part_3_333\tEncoder भावनात्मक रुपमा सक्रिय भए\n',
#  'ku_hackfest_part_3_334\tJun\n',
#  'ku_hackfest_part_3_335\tआर्थिकरुपमा\n',
#  'ku_hackfest_part_3_336\tदेखा पर्यो उनले त्यो डरलाई यसले j3\n',
#  'ku_hackfest_part_3_337\tदिनको तीनपटक uniquode माइती बस्ने\n',
#  'ku_hackfest_part_3_338\tसिंहको syntocin brochure erc tapari आँखा बन्द गरिन् उनले आफ्नो तन मलाई सधैं स्थिर र शान्त राखी\n',
#  'ku_hackfest_part_3_339\tधार्मिक विश्राम le\n',
#  'ku_hackfest_part_3_340\tमानसिक शान्ति बढाइ\n',
#  'ku_hackfest_part_3_341\tमलाई सुझावप्रति ग्रहण शिर बनाउँछ\n',
#  'ku_hackfest_part_3_342\tउनले भयलाई प्रभावहीन बनाउन आफूलाई भन्दै गईन\n',
#  'ku_hackfest_part_3_343\tम सुमधुर गाउन सक्छु\n',
#  'ku_hackfest_part_3_344\tम नियन्त्रित\n',
#  'ku_hackfest_part_3_345\t2013 आफ्नो विश्वासिलो शान्त छ\n',
#  'ku_hackfest_part_3_346\tहरिण बसाइमा उनले यी भावना 5 देखि 10 पटकसम्म\n',
#  'ku_hackfest_part_3_347\tपूर्वका 72 in\n',
#  'ku_hackfest_part_3_348\tहरेक दिन उनी तीनपटक wesley बस्ने गर्थिन्\n',
#  'ku_hackfest_part_3_349\tसुत्नुअघि पनि एकपटक गराउने गर्थे\n',
#  'ku_hackfest_part_3_350\tएक हप्ता kavyaschool पिउने पूर्ण विश्वस्त liscen थिइन्\n',
#  'ku_hackfest_part_3_351\tनिःशुल्क लागि जब उनलाई बोलाइयो\n',
#  'ku_hackfest_part_3_352\tउनले austin mohone ढङ्गमा dine\n',
#  'ku_hackfest_part_3_353\tकसरी उनले आफ्नो स्मरणशक्ति फिर्ता पाइने\n',
#  'ku_hackfest_part_3_354\t175 वर्ष vedha आफ्नो सम्झने क्षमता घट्दै गइरहेको भाव\n',
#  'ku_hackfest_part_3_355\tDuriya hai\n',
#  'ku_hackfest_part_3_356\tउनले yuvani बदलेर सकारात्मक भाव हराउन थालिन्\n',
#  'ku_hackfest_part_3_357\tAajo अहिलेबाट niro सम्झने शक्तिमा\n',
#  'ku_hackfest_part_3_358\tआधारभूत\n',
#  'ku_hackfest_part_3_360\tBhumi समय र परिस्थिति मपनि\n',
#  'ku_hackfest_part_3_361\tम\n',
#  'ku_hackfest_part_3_362\tMili सम्झनुपर्ने हरेक कुरासँग नसक्ने भएको छु\n',
#  'ku_hackfest_part_3_363\tLeaague गर्नु खोजीका सम्पूर्ण विवरण अझै स्पष्ट losahar भइरहेछ\n',
#  'ku_hackfest_part_3_364\tऔषधीलाई पुनरावृत्ति गर्नसक्छ\n',
#  'ku_hackfest_part_3_365\tMuli पुनरावृत्ति गर्नुस् आएका हरेक विवरण\n',
#  'ku_hackfest_part_3_366\tपहिलोपटक आउनसक्छ miruti स्वरमा धेरै सुधार भएको छ\n',
#  'ku_hackfest_part_3_367\tअनि चाँडै नै मैले\n',
#  'ku_hackfest_part_3_368\tअहिले हुम्ला\n',
#  'ku_hackfest_part_3_369\tधेरै राम्रो isnot शक्ति पाउने छ\n',
#  'ku_hackfest_part_3_370\tनभएपछि उनले पहिलेजस्तै is march ke\n',
#  'ku_hackfest_part_3_371\tHa sugery no full movie\n',
#  'ku_hackfest_part_3_372\tकसरी उनले अप्रसन्न स्वभाव माथि vijayta\n',
#  'ku_hackfest_part_3_373\tतनावग्रस्त मन्द छिटो रिस उठ्ने बानीको कारणले\n',
#  'ku_hackfest_part_3_374\tचिन्तित धेरै व्यक्तिहरुमा आफ्नो सुझावले\n',
#  'ku_hackfest_part_3_375\tउल्लेखनीय प्रभाव पारेको\n',
#  'ku_hackfest_part_3_376\tअद्भुत matija दिएको\n',
#  'ku_hackfest_part_3_377\tउदाहरण प्रशस्त छन्\n',
#  'ku_hackfest_part_3_378\tNewly दिनको तीनपत्ती बिहान दिउँसो र साँझ नसुत murgi\n',
#  'ku_hackfest_part_3_379\tनिम्न सुझाव ल्याएका थिए\n',
#  'ku_hackfest_part_3_380\tअहिलेदेखि\n',
#  'ku_hackfest_part_3_381\tम\n',
#  'ku_hackfest_part_3_382\tसजिलो माइलो भन्छ\n',
#  'ku_hackfest_part_3_383\tअपाङ्ग प्रति हाम्रो मनको सामान्य अवस्था बन्दैछ\n',
#  'ku_hackfest_part_3_384\tम आफूलाई चिन्ने मसँग भेट्ने hermatic उमंग\n',
#  'ku_hackfest_part_3_385\tर सदभावको केन्द्र भइरहेको छ\n',
#  'ku_hackfest_part_3_386\tNew कारणले उनीहरू पनि आनन्दित भइरहेका\n',
#  'ku_hackfest_part_3_387\tRheum हकप्र कुलत\n',
#  'ku_hackfest_part_3_388\tतारानन्द मेरो सामान्य स्थिति बनेको छ\n',
#  'ku_hackfest_part_3_389\tम धन्य छु\n',
#  'ku_hackfest_part_3_390\tझापाको विकासशील\n',
#  'ku_hackfest_part_3_391\tविनाशकारी शक्ति\n',
#  'ku_hackfest_part_3_392\tAnu sujab ko व्याख्या र समीक्षा\n',
#  'ku_hackfest_part_3_393\tबरु सुझावको अर्थ अरुका विशाल नेपालको प्रभाव\n',
#  'ku_hackfest_part_3_394\tउनैको हरेक कालखण्डमा सुझावको सक्कली मानिसको विचार एवं सम्पूर्ण जीवन मा नै गहिरो प्रभाव पारेको देखिन्छ\n',
#  'ku_hackfest_part_3_395\tविश्वका धेरै मुलुकहरुमा सुझाव नै\n',
#  'ku_hackfest_part_3_396\tधर्मको नियन्त्रण शक्ति बनेको छ मनको सामान्य विज्ञानको ज्ञान नभएका व्यक्तिलाई\n',
#  'ku_hackfest_part_3_397\tहुन्छ सित अनियन्त्रित aafnai सञ्चालन गर्न प्रत्यक्ष\n',
#  'ku_hackfest_part_3_398\tया अप्रत्यक्ष रुपमा सुझाव पेश गर्न सकिन्छ रचनात्मक पक्षमा सुझाव को प्रभाव\n',
#  'ku_hackfest_part_3_399\tअति हौत रहन्छ\n',
#  'ku_hackfest_part_3_400\tनकारात्मक प्रयोगमा सुझाव नै मनको प्रयोग मध्येको सबैभन्दा विनाशकारी प्रतिक्रिया आउँछ जसले दरिद्रता असफलता पीडा\n',
#  'ku_hackfest_part_3_401\tरोगको प्रकोप निम्त्याउँछ\n',
#  'ku_hackfest_part_3_402\tतपाईंले यसमध्ये कुनै स्वीकार्नु भएको छ\n',
#  'ku_hackfest_part_3_403\tबालिका देखिने हामीमध्ये अधिकांशले\n',
#  'ku_hackfest_part_3_404\tसुकरात makes सुझाव दियो हुर्काइएको छ\n',
#  'ku_hackfest_part_3_405\tउनले मूल्यांकन गर्न\n',
#  'ku_hackfest_part_3_406\tर स्वीकार गर्न नजानेर\n',
#  'ku_hackfest_part_3_407\tहामी सजिलै अंगीकार गर्छौ\n',
#  'ku_hackfest_part_3_408\tनकारात्मक सुझाव\n',
#  'ku_hackfest_part_3_409\tयस प्रकाशन\n',
#  'ku_hackfest_part_3_410\tतिमी सक्दैनौ तिमी कै भन्ने छैन\n',
#  'ku_hackfest_part_3_411\tEngli गर्नुहुँदैन\n',
#  'ku_hackfest_part_3_412\tTiny हाल्नेछ\n',
#  'ku_hackfest_part_3_413\tतिमीसँग क्षमता छैन\n',
#  'ku_hackfest_part_3_414\tतिमीसँगै गलत हुन्छ\n',
#  'ku_hackfest_part_3_415\tRebecca show\n',
#  'ku_hackfest_part_3_416\tयो गर्नुभएका\n',
#  'ku_hackfest_part_3_417\tतिमीलाई थाहा भएको होला तिमीले\n',
#  'ku_hackfest_part_3_418\tकसले निकास हो\n',
#  'ku_hackfest_part_3_419\tयो महत्त्वपूर्ण हुन्छ\n',
#  'ku_hackfest_part_3_420\tकसैले वास्ता छैन तिमी किन वास्ता गर्छ\n',
#  'ku_hackfest_part_3_421\tI3 and गर्नुभएका हरु\n',
#  'ku_hackfest_part_3_422\tपरिस्थिति झन बर्बाद भएको छ\n',
#  'ku_hackfest_part_3_423\tVen\n',
#  'ku_hackfest_part_3_424\tउहाँहरुका लागि मात्र\n',
#  'ku_hackfest_part_3_425\tजन्मसँगै क्युवाको रुपमा प्रगति सर्वं\n',
#  'ku_hackfest_part_3_426\tरचनात्मक आफ्नो सुझाव sanshar गरिँदैन\n',
#  'ku_hackfest_part_3_427\tपुरानो एकात्मक सुझावका प्रभाव\n',
#  'ku_hackfest_part_3_428\tहावी भएर हामीलाई\n',
#  'ku_hackfest_part_3_429\tव्यक्तिगत\n',
#  'ku_hackfest_part_3_430\tर सामाजिक जीवन म\n',
#  'ku_hackfest_part_3_431\tसफलता भोग्न बाध्य बनाई रहन्छ\n',
#  'ku_hackfest_part_3_432\tBasanta\n',
#  'ku_hackfest_part_3_433\tआत्म सुझावको महान kariyo\n',
#  'ku_hackfest_part_3_434\tजस्ले तपाई महान सोच र\n',
#  'ku_hackfest_part_3_435\tMaham देवहरि स्थापित गर्ने कमलाई अवरुद्ध ल्याउनेछन् कुर्सी धारालाई तोड्न र एउटा स्वतन्त्र एवं\n',
#  'ku_hackfest_part_3_436\tMaham रक्षाको लागि जिउन\n',
#  'ku_hackfest_part_3_437\tउपप्रधान गर्दछ\n',
#  'ku_hackfest_part_3_439\tनकरात्मक सुझावलाई प्रतिवाद गर्न सकिन्छ\n',
#  'ku_hackfest_part_3_440\tकुनै पत्रिका पढ्नु भयो भने तपाईले दर्जनौ यस्ता\n',
#  'ku_hackfest_part_3_441\tखबरहरु पाउनुहुन्छ\n',
#  'ku_hackfest_part_3_442\tजसले तपाइमा डर plasin का प्रमाण\n',
#  'ku_hackfest_part_3_443\tरहनु सिर्जना गर्दछ\n',
#  'ku_hackfest_part_3_444\tअहिले यही भावलाई स्वीकार गरेको खण्डमा\n',
#  'ku_hackfest_part_3_445\tPaimon जीवनप्रतिको\n',
#  'ku_hackfest_part_3_446\tहुनुहुन्छ\n',
#  'ku_hackfest_part_3_447\tअवचेतन मनमा संचालित हुने nakap ऊ विचारलाई प्रतिवाद गर्न सकिन्छ भन्ने क्याम बाट तपाईले भातको सट्टा अन्य उर्जाशील\n',
#  'ku_hackfest_part_3_448\tजीवन दाहिने भाग सम्प्रेषण गर्न सक्नुहुन्छ\n',
#  'ku_hackfest_part_3_449\tभएको ओरिपरी caractor water आउने\n',
#  'ku_hackfest_part_3_450\tNarka प्रभावलाई नियाल्न कोष\n',
#  'ku_hackfest_part_3_451\tपैसा बाट प्रभावित हुनु तपाईंको छनोट\n',
#  'ku_hackfest_part_3_452\tओली मुल्याङ्कन गर्नुहोस्\n',
#  'ku_hackfest_part_3_453\tRahulshah दिने भाव\n',
#  'ku_hackfest_part_3_454\tअंगिकार गरेर\n',
#  'ku_hackfest_part_3_455\tबाँकी फिर्ता दिनुहोस्\n',
#  'ku_hackfest_part_3_456\tहामी सबैजना जीवनका विभिन्न मोडमा यस्ता काठमाडौंबाट पिरोलिएका छन्\n',
#  'ku_hackfest_part_3_457\tफर्केर हेर्ने भने\n',
#  'ku_hackfest_part_3_458\tहामीले सजिलैसँग सक्छौं\n',
#  'ku_hackfest_part_3_459\tघडि हाम्रा अभिभावक साथीलाई नातेदार शिक्षकका आफन्त नकारात्मक सुझावको\n',
#  'ku_hackfest_part_3_460\tHamne सहभागी भएका थिए\n',
#  'ku_hackfest_part_3_461\tछैन भनेका कुराहरु मूल्याङ्कन गर्दै जाने हो भने ती सम्मका probab\n',
#  'ku_hackfest_part_3_462\tभने नियन्त्रणमा राख्नु\n',
#  'ku_hackfest_part_3_463\tमा तपाईं मद्दत पैदा गर्नु भनि\n',
#  'ku_hackfest_part_3_465\tसुझाव हरेक घर कारणले कारखाना\n',
#  'ku_hackfest_part_3_466\tAni\n',
#  'ku_hackfest_part_3_467\tहरेक समूहमा विद्यमान हुन्छ\n',
#  'ku_hackfest_part_3_468\tHimadri अधिकांश परशुराम हरूको उद्देश्य तपाईंलाई अरुले छाया लोप हुनुको फाइदा हरु को\n',
#  'ku_hackfest_part_3_469\tअनुभव गर्नु वा कार्य गर्न प्रेरित गति प्रयोजनले व्यक्त गरिएको\n',
#  'ku_hackfest_part_3_470\tकसरी सुझावले मान्छे माग\n',
#  'ku_hackfest_part_3_471\tयहाँ parshadhap प्रभावबारे व्याख्या गरिएको छ\n',
#  'ku_hackfest_part_3_472\tमेरो एकजना नातेदार पृष्ठ हेर्न भबिस्यबाणी आउने भारतीय ज्योतिषीका पुगे\n',
#  'ku_hackfest_part_3_473\tउनले भनिएकी\n',
#  'ku_hackfest_part_3_474\tउनको mukhra भैसक्यो\n',
#  'ku_hackfest_part_3_475\tDownloa पूर्णिमामा उनको मृत्यु हुन्छ\n',
#  'ku_hackfest_part_3_476\tLabels सम्पूर्ण सदस्यलाई सो कुरा जानकारी गराएर संपत्ति नामसारि पनि गरिदै\n',
#  'ku_hackfest_part_3_477\tउनले पूर्ण रुपमा स्वीकार गरेको leeu शक्तिशाली सुझाव कुन कवज magar\n',
#  'ku_hackfest_part_3_478\tHati दाहाललाई यो पनि भनेको थियो कि\n',
#  'ku_hackfest_part_3_479\tउक्त भविष्यवक्ता मा यस्तो शक्तिसँग जसको प्रयोगले uk 80 माथि कृपा वा हानी गर्न सक्थे\n',
#  'ku_hackfest_part_3_480\tआफ्नो मनको कार्यशैली र कार्यक्षमताको अज्ञानताका कारण\n',
#  'ku_hackfest_part_3_481\tअनुमानित समयमा neymar\n',
#  'ku_hackfest_part_3_482\tटोकिपनी\n',
#  'ku_hackfest_part_3_483\tहामीमध्ये धेरैले यस्तै अन्धविश्वास\n',
#  'ku_hackfest_part_3_484\tमूर्ख तारहरु ज्ञानले भरि\n',
#  'ku_hackfest_part_3_485\tकथा सुनेका छन्\n',
#  'ku_hackfest_part_3_486\tयस घटनालाई\n',
#  'ku_hackfest_part_3_487\tअवचेतन मनको कार्यशैलीको ज्ञानको प्रकाशमा\n',
#  'ku_hackfest_part_3_488\tविश्लेषण\n',
#  'ku_hackfest_part_3_489\tRitu मुरलीधरको को आधारमा विश्वास पनि स्वीकार गर्ने\n',
#  'ku_hackfest_part_3_490\tऋण विवरण lagayat malik अंगिकार गर्दछ\n',
#  'ku_hackfest_part_3_491\tHisimati घारी गर्दछ\n',
#  'ku_hackfest_part_3_492\tज्योतिषी कहाँ जानुअघि\n',
#  'ku_hackfest_part_3_493\tनीर नातेदार सुस्त kosila मन जित्यो\n',
#  'ku_hackfest_part_3_494\tहुनलाई अति नकारात्मक सुझाव दियो\n',
#  'ku_hackfest_part_3_495\tजुन उनले स्वीकार गरे\n',
#  'ku_hackfest_part_3_496\tउनी prashil भए\n',
#  'ku_hackfest_part_3_497\tर आफु अर्को पूर्णिमा मर्दैछु भन्ने कुरा\n',
#  'ku_hackfest_part_3_498\tमनमा खेलाएर\n',
#  'ku_hackfest_part_3_499\tउनले धेरैलाई विश्वासका साथ\n',
#  'ku_hackfest_part_3_500\tकुरा सुनाई\n',
#  'ku_hackfest_part_3_501\tRum तिमीलाई को तयारी पनि गरे\n',
#  'ku_hackfest_part_3_502\tविश्वका\n',
#  'ku_hackfest_part_3_503\tउनको मनमा छैन\n',
#  'ku_hackfest_part_3_504\tरिसको कारण\n',
#  'ku_hackfest_part_3_505\tउनको विचार थियो\n',
#  'ku_hackfest_part_3_506\tउनी आफूले भन्दै\n',
#  'ku_hackfest_part_3_507\tBrusli आफ्नो मृत्यु\n',
#  'ku_hackfest_part_3_508\tभौतिक शरिरको बिना smith\n',
#  'ku_hackfest_part_3_509\tउनलाई भविष्य बताउने महिलामा\n',
#  'ku_hackfest_part_3_510\tत्रिलक्षण पत्रमाथि कुनै शक्ति\n',
#  'ku_hackfest_part_3_512\tउनको सुझावमा यो नतिजा ल्याउने कुनै सामर्थ्य\n',
#  'ku_hackfest_part_3_513\tउनले आफ्नो मनको कार्यशैलीको ज्ञान राखेको भई\n',
#  'ku_hackfest_part_3_514\tआफु आफ्नै विषालु भावना र नियन्त्रित पनि संचालित छन् भन्ने ज्ञान नभएको\n',
#  'ku_hackfest_part_3_515\tअनुपात मुख्य लाभलाई उनले\n',
#  'ku_hackfest_part_3_516\tअस्वीकार गरेर त्यसलाई\n',
#  'ku_hackfest_part_3_517\tबेवास्ता गर्न सक्थे\n',
#  'ku_hackfest_part_3_518\tयुद्ध हाल आनीको 3\n',
#  'ku_hackfest_part_3_519\tVicar गरेझैं\n',
#  'ku_hackfest_part_3_520\tसुझावहरु\n',
#  'ku_hackfest_part_3_521\tनिस्तेज पार्न सकिन्थ्यो\n',
#  'ku_hackfest_part_3_522\tमनको विज्ञानको सामुन्ने प्रयोगले पनि उक्त भविष्यवाणीलाई प्रभावहीन बनाउन सकिने थियो\n',
#  'ku_hackfest_part_3_523\tअरु बच्चा हुने सुझावमा त्यतिन्जेलसम्म कुनै शक्ति हुँदैन\n',
#  'ku_hackfest_part_3_524\tजबसम्म हामीले आफ्नो विचार अभावका साथै यसलाई स्वीकार गर्दैन\n',
#  'ku_hackfest_part_3_526\tहामी लिप सुझाव स्वीकार गर्छौं उक्त सुझावले\n',
#  'ku_hackfest_part_3_527\tभूतको भाव प्रदर्शन गर्छ\n',
#  'ku_hackfest_part_3_528\tयसको लागि तपाईंले manushya कनु mati\n',
#  'ku_hackfest_part_3_529\tMeaning\n',
#  'ku_hackfest_part_3_531\tअहिले सो विचारलाई स्वीकार गर्ने पर्छ\n',
#  'ku_hackfest_part_3_532\tIs अवस्थामा ती विशाल तपाईंको घर जान्छ\n',
#  'ku_hackfest_part_3_533\tरबल्छि taman त्यसलाई यथार्थ वनतिर लाग्छ\n',
#  'ku_hackfest_part_3_534\tयाद राख्नुस् तपाईंसँग छनोटको अधिकार छ\n',
#  'ku_hackfest_part_3_535\tजीवन रोज्नुहोस\n',
#  'ku_hackfest_part_3_536\tWindows\n',
#  'ku_hackfest_part_3_537\tभ्रष्ट रोज्नुहोस\n',
#  'ku_hackfest_part_3_539\tमान्यताको saddhi\n',
#  'ku_hackfest_part_3_540\tघाँसी मुहानको समयदेखि das nikka तर्कशास्त्र हरुले\n',
#  'ku_hackfest_part_3_541\tXizang नामक तर्क शैलीको अध्ययन गरेका छन्\n',
#  'ku_hackfest_part_3_542\tSyllogism ma मस्तिष्कको व्यवहारिक कुरा म तर्क गर्दछ यसको अर्थ तपाइँको क्षेत्र nmon\n',
#  'ku_hackfest_part_3_543\tजुन प्रमुख विचारलाई सत्यमान छ त्यो विशाल नै अवस्थित janmauxa\n',
#  'ku_hackfest_part_3_544\tप्रतिक्रिया दिन्छ त्यही सरुवा समस्या के कस्तो छ भन्ने कुराले केही फरक पार्दैन\n',
#  'ku_hackfest_part_3_545\tयदि प्रमुख बिचार सहि सपनि\n',
#  'ku_hackfest_part_3_546\tनिष्कर्ष पनि अवस्थी निष्क्रिय हुन्छ\n',
#  'ku_hackfest_part_3_547\tउदाहरणको लागि\n',
#  'ku_hackfest_part_3_548\tजुन कलेजका व्यापक townhall\n',
#  'ku_hackfest_part_3_549\tNew krish3\n',
#  'ku_hackfest_part_3_550\tमनको विज्ञान विषयमा\n',
#  'ku_hackfest_part_3_551\tMuliki प्रदर्शनको कक्षाले kaathi\n',
#  'ku_hackfest_part_3_552\tउनले malai dukhi sukhi\n',
#  'ku_hackfest_part_3_553\tमेरो जिबनमा\n',
#  'ku_hackfest_part_3_554\tHari\n',
#  'ku_hackfest_part_3_555\tबोक्सी लथालिङ्ग छ\n',
#  'ku_hackfest_part_3_556\tमिलि स्वास्थ्य सम्पत्ति र साथीहरु सबै गुमाएको छ\n',
#  'ku_hackfest_part_3_557\tमैले जहाँ चाह्यो\n',
#  'ku_hackfest_part_3_558\tबिग्रिन्छ\n',
#  'ku_hackfest_part_3_559\tउनले अब\n',
#  'ku_hackfest_part_3_560\tअवचेतन मनको यथाशक्ति\n',
#  'ku_hackfest_part_3_561\tर अनन्त सम्भावनाले आफूलाई आध्यात्मिक\n',
#  'ku_hackfest_part_3_562\tमानसिक र भौतिक प्रगति र निर्देशित गरेको यथार्थलाई\n',
#  'ku_hackfest_part_3_563\tआधारभूत मान्यता बनाउनुपर्छ भने\n',
#  'ku_hackfest_part_3_564\tमैले जोडले अनिमात्र अवस्थी मन्दिर पूर्ण विवेक साथ उनको लगानी र निर्माणमा सहयोग पुर्याउने\n',
#  'ku_hackfest_part_3_565\tRicoh उपचार गर्ने\n',
#  'ku_hackfest_part_3_566\tजीवनमा शान्ति समृद्धि स्थापना गर्ने कुरा पनि\n',
#  'ku_hackfest_part_3_567\tमैले उनलाई बताए\n',
#  'ku_hackfest_part_3_568\tTiptop उक्लि त्यसपछि उनले चाहनुको परिस्थितिको मानसिक क्षेत्र\n',
#  'ku_hackfest_part_3_569\tरुपरेखा तयार गरी\n',
#  'ku_hackfest_part_3_570\tजुनको आधारभूत मान्यतालाई\n',
#  'ku_hackfest_part_3_571\tभास्वती हरेक यात्रमा मलाई gaya आएको छ\n',
#  'ku_hackfest_part_3_572\tमार्ग निर्देशन गरिरहेको हुन्छ\n',
#  'ku_hackfest_part_3_573\tMakur रुपमा सोच्दछु\n',
#  'ku_hackfest_part_3_574\tThamelcom anemone सन्तुलित छ\n',
#  'ku_hackfest_part_3_575\tGorkha प्रेम राम्रो सम्पन्नता मेरै हुन्\n',
#  'ku_hackfest_part_3_576\tसुकर्मका देवदह आशाले मेरो जीवन सञ्चालीत छ\n',
#  'ku_hackfest_part_3_577\tNiru छेतन मनको बैशाख प्रणालीहरु सार्ने\n',
#  'ku_hackfest_part_3_578\tअवचेतन मनले\n',
#  'ku_hackfest_part_3_579\tCabin छ भन्ने कुरा\n',
#  'ku_hackfest_part_3_580\tमलाई थाहा छ यो मेरो हुनु भनेर विश्वास गर्ने छोड\n',
#  'ku_hackfest_part_3_581\tउनले मलाई यस्तो पत्र पठाए\n',
#  'ku_hackfest_part_3_582\tManmanai दिनको दुई पटक मैले यी भाव गर्याे\n',
#  'ku_hackfest_part_3_583\tर अनुभव गरेकी\n',
#  'ku_hackfest_part_3_584\tमैले duyae क\n',
#  'ku_hackfest_part_3_585\tहरेक भावहरु\n',
#  'ku_hackfest_part_3_586\tअवचेतन मनको गहिराइमा पुगेर यथार्थ निर्माण गर्दै थिए\n',
#  'ku_hackfest_part_3_587\tआफ्नो अन्त baamalai दिनुभएकोमा\n',
#  'ku_hackfest_part_3_588\tधन्यवाद\n',
#  'ku_hackfest_part_3_589\tयो पनि हुने गर्न छाम्छु\n',
#  'ku_hackfest_part_3_590\tमेरो जीवनका हरेक पक्षमा सरकारमा परिवर्तन आएको छ\n',
#  'ku_hackfest_part_3_591\tभएको सुझावले\n',
#  'ku_hackfest_part_3_592\tBhoj\n',
#  'ku_hackfest_part_3_593\tकाम गर्दछ\n',
#  'ku_hackfest_part_3_594\tअवचेतन ले विभाग गर्दैन अवचेतन म सम्पूर्ण ज्ञान छ\n',
#  'ku_hackfest_part_3_595\tIs naharik प्रश्नका उत्तर सुन्\n',
#  'ku_hackfest_part_3_596\tउसले तपाईसँग नौलो कुरा गर्ने\n',
#  'ku_hackfest_part_3_597\tमैले दिएको तर्कलाई विश्लेषण गर्दैन\n',
#  'ku_hackfest_part_3_598\tउदाहरणको लागि\n',
#  'ku_hackfest_part_3_599\tजब तपाई\n',
#  'ku_hackfest_part_3_600\tम सक्दिन म बुढो भइसकें\n',
#  'ku_hackfest_part_3_601\tमृत्यु पूरा गर्नसक्दैन\n',
#  'ku_hackfest_part_3_602\tMucho पदको backpain भन्नुहुन्छ\n',
#  'ku_hackfest_part_3_603\tत्यसबेला तपाइँ\n',
#  'ku_hackfest_part_3_604\tआफ्नो अवचेतन मनलाई\n',
#  'ku_hackfest_part_3_605\tनकारात्मक सुझावले भर्दै हुनुहुन्छ\n',
#  'ku_hackfest_part_3_606\tJune 10\n',
#  'ku_hackfest_part_3_607\tयथार्थको रूपमा देखापर्छ\n',
#  'ku_hackfest_part_3_608\tहसमत पनि आफ्नो प्रगति रोक्दै हुनुहुन्छ\n',
#  'ku_hackfest_part_3_609\tरतलाम habsi नेताहरु तनाव निम्त्याउँछ\n',
#  'ku_hackfest_part_3_610\tसर्वोच्च तनमन मार्फत दादा ruaaune बेला सुस्ती अघि सार्नु हुन्छ\n',
#  'ku_hackfest_part_3_611\tत्यतिबेला तपाईं अवस्थित मनको ज्ञान शक्ति अस्तित्व\n',
#  'ku_hackfest_part_3_612\tर प्रभाव\n',
#  'ku_hackfest_part_3_613\tघरैमा हुन्छ\n',
#  'ku_hackfest_part_3_614\tभएको अवश्य हुन् उनले तपाईंको समस्या समाधान गर्न सक्दैन भन्ने भावलाई\n',
#  'ku_hackfest_part_3_615\tReady बाची मान्दै हुनुहुन्छ\n',
#  'ku_hackfest_part_3_616\tयसले\n',
#  'ku_hackfest_part_3_617\tमानसिक रसायनिक सुत्र बढाउदै\n',
#  'ku_hackfest_part_3_618\tबीमारी\n',
#  'ku_hackfest_part_3_619\tमानसिक असन्तुलन निम्त्याउछ\n',
#  'ku_hackfest_part_3_620\tतनावबाट मुक्त भई\n',
#  'ku_hackfest_part_3_621\tआफ्नो इच्छा पूर्ति भन\n',
#  'ku_hackfest_part_3_622\tBharam bar dhaka 7 गराउनुहोस् कि त्यो पार्षद ती जसले मलाई\n',
#  'ku_hackfest_part_3_623\tChhadeyo ओसिलि malai\n',
#  'ku_hackfest_part_3_624\tआफ्नो लक्ष्य पूर्ति को अचुक तरिका उजागर गर्दै\n',
#  'ku_hackfest_part_3_625\tमार्ग निर्देशन गर्छ\n',
#  'ku_hackfest_part_3_626\tमलाई थाहा छ\n',
#  'ku_hackfest_part_3_627\tमभित्र कथा shakti\n',
#  'ku_hackfest_part_3_628\tर अनन्त सम्भावना\n',
#  'ku_hackfest_part_3_629\tUgly सक्रिय\n',
#  'ku_hackfest_part_3_630\tमैले मनमनै himanshu\n',
#  'ku_hackfest_part_3_631\tझूठा msu ती कुरा बाहिर घटना र परिस्थितिको रुपमा\n',
#  'ku_hackfest_part_3_632\tदेखापर्दछ\n',
#  'ku_hackfest_part_3_633\tयहाँ सन्तुलन\n',
#  'ku_hackfest_part_3_634\tसहिष्णुता\n',
#  'ku_hackfest_part_3_635\tक्षमता छ\n',
#  'ku_hackfest_part_3_636\tयदि तपाईले कुनै उपाय छैन\n',
#  'ku_hackfest_part_3_637\tम हारे\n',
#  'ku_hackfest_part_3_638\tYou\n',
#  'ku_hackfest_part_3_639\tविविधा kunika saina\n',
#  'ku_hackfest_part_3_640\tम\n',
#  'ku_hackfest_part_3_641\tअशक्त\n',
#  'ku_hackfest_part_3_642\tअब भने भन्नुहुन्छ भने कैदी अवचेतन मनबाट कुनै सहयोगको आशा प्रतिक्रिया पाउनुहुन्न\n',
#  'ku_hackfest_part_3_643\tअवचेतन मनले आफ्नो लागे कार्य गरोस् भन्ने छर्लंग छ भनी सही आगमन\n',
#  'ku_hackfest_part_3_644\tयसको सहयोग प्राप्त गर्नुहोस्\n',
#  'ku_hackfest_part_3_645\tयो सन्धि तपाईंकै लागि काम गर्छ\n',
#  'ku_hackfest_part_3_646\tतपाईंको मुटुको dharkan anish श्वास प्रणाली सञ्चालन गरिनेछ\n',
#  'ku_hackfest_part_3_647\tयसले तपाईंलाई नलागेको घाउचोट निको पार्दछ\n',
#  'ku_hackfest_part_3_648\tरिसको प्रविधि जिबनलाई knees\n',
#  'ku_hackfest_part_3_649\tजसले सधैं तपाईंको सुरक्षा र सफलताको लागि काम गर्दछ\n',
#  'ku_hackfest_part_3_650\tअवचेतन मनको आफ्नै व्यवस्था भएपनि\n',
#  'ku_hackfest_part_3_651\tयसले तपाइको बेसार र क्षेत्रलाई स्वीकार गर्दछ\n',
#  'ku_hackfest_part_3_652\tBhandi कुनै समस्याको समाधान खोल्दै हुनुहुन्छ भने\n',
#  'ku_hackfest_part_3_653\tअवचेतन मनले सहयोग गर्छ\n',
#  'ku_hackfest_part_3_654\tयस शर्तमा गित तपाईंले छेत्री मनको प्रयोग\n',
#  'ku_hackfest_part_3_655\tमूल्यांकन गरी स्पष्ट niger nu पर्दछ\n',
#  'ku_hackfest_part_3_656\tबताइन्\n',
#  'ku_hackfest_part_3_657\tMuku निकास देख्दिन महल मासु भन्नुहुन्छ तपाईं आफ्नो उर्जा\n',
#  'ku_hackfest_part_3_658\tनिस्तेज पार्दै हुनुहुन्छ\n',
#  'ku_hackfest_part_3_659\tParinka सिपाहीहरुले झैं तपाईंले पनि धेरै शक्ति खर्च गर्नुहुन्छ\n',
#  'ku_hackfest_part_3_661\tकतै पुग्नुहुन्छ\n',
#  'ku_hackfest_part_3_662\tभिसाको प्रभाव शान्त पार्नुस्\n',
#  'ku_hackfest_part_3_663\tशरीर सिथिल पार्नुहोस् lalum सँग भन्नुहोस्\n',
#  'ku_hackfest_part_3_664\tNirohawa तनमनले\n',
#  'ku_hackfest_part_3_665\tउत्तर jhamara\n',
#  'ku_hackfest_part_3_666\tनिलो भावनामाथि प्रतिक्रिया जनाउँदै छ\n',
#  'ku_hackfest_part_3_667\tम धन्य छु की अब sumitra कथा shakti\n',
#  'ku_hackfest_part_3_668\tरहन्छ सम्भावनामा\n',
#  'ku_hackfest_part_3_669\tहरेक कुराको ज्ञान छ भन्ने त\n',
#  'ku_hackfest_part_3_671\tमलाई थाहा छ\n',
#  'ku_hackfest_part_3_672\tयसले मलाई सहि मार्ग निर्देशन दिइरहेछ\n',
#  'ku_hackfest_part_3_673\tमेरो दृढ विश्वास ले\n',
#  'ku_hackfest_part_3_674\tमभित्रको गौरव\n',
#  'ku_hackfest_part_3_675\tमहामाता उजागर गर्दै छ\n',
#  'ku_hackfest_part_3_676\tयस्तो भएको म\n',
#  'ku_hackfest_part_3_677\tMahananda s6\n',
#  'ku_hackfest_part_3_678\tसम्झनै पर्ने कुराहरु\n',
#  'ku_hackfest_part_3_680\tराम्रो सोच्नुभयो भने राम्रो हुनेछ\n',
#  'ku_hackfest_part_3_681\tनराम्रो सक्नुभयो भने\n',
#  'ku_hackfest_part_3_682\tनराम्रो हुनेछ\n',
#  'ku_hackfest_part_3_683\tहिँडे बन्नुहुन्छ\n',
#  'ku_hackfest_part_3_684\tजुन तपाई\n',
#  'ku_hackfest_part_3_685\tInversions रुन्छ\n',
#  'ku_hackfest_part_3_686\tBri\n',
#  'ku_hackfest_part_3_687\tMike अवचेतन मन तपाईंसँग बहस गर्दैन\n',
#  'ku_hackfest_part_3_688\tयो तपाईंको चेतन मनका देशलाई चुपचाप मान्दछ\n',
#  'ku_hackfest_part_3_689\tम\n',
#  'ku_hackfest_part_3_690\tयत्रो खर्च गर्न सक्दैन भन्नुभयो भने\n',
#  'ku_hackfest_part_3_691\tभएको अवश्य तिनले\n',
#  'ku_hackfest_part_3_692\tत्यसलाई साँचो बनाउने काम गर्न थाल्दछ\n',
#  'ku_hackfest_part_3_693\tकुनै\n',
#  'ku_hackfest_part_3_694\tज्यादै राम्रो विचार छान्नुहोस्\n',
#  'ku_hackfest_part_3_695\tबरु यो आदेश दिनुहोस्\n',
#  'ku_hackfest_part_3_696\tMotilai किन्ने छ\n',
#  'ku_hackfest_part_3_697\tमधेसलाई आफ्नो मनमा स्वीकार गर्छ\n',
#  'ku_hackfest_part_3_699\tफैशन खानी सतिसाल\n',
#  'ku_hackfest_part_3_700\tस्वास्थ्री र खुसीलाई हाम्रो\n',
#  'ku_hackfest_part_3_701\tहिँउ mithuwa त सतुवा\n',
#  'ku_hackfest_part_3_702\tको हुन् भनेर छान्न सक्नुहुन्छ\n',
#  'ku_hackfest_part_3_703\tसहयोगी खोसिने मित्रता प्रेम गर्न\n',
#  'ku_hackfest_part_3_704\tयोग्य banma छौं गर्नुहुन्छ भने\n',
#  'ku_hackfest_part_3_705\tभारत संसारले प्रत्येक क्या गर्नेछ\n',
#  'ku_hackfest_part_3_706\tब्याक्तित्व विकसित गर्ने\n',
#  'ku_hackfest_part_3_707\tहामीभन्दा\n',
#  'ku_hackfest_part_3_708\tराम्रो तरिका यो\n',
#  'ku_hackfest_part_3_709\tझाड\n',
#  'ku_hackfest_part_3_710\tतपाईंको क्षेत्र मन्तालय हो\n',
#  'ku_hackfest_part_3_711\tयसको प्रमुख काम झुटो भाव प्रभावबाट\n',
#  'ku_hackfest_part_3_712\tभएको oversleeping मनलाई\n',
#  'ku_hackfest_part_3_713\tरक्षा गर्नु\n',
#  'ku_hackfest_part_3_714\tकुनै राम्रो चिज हुनसक्दछ\n',
#  'ku_hackfest_part_3_715\tअहिले भइरहेको छ भन्ने\n',
#  'ku_hackfest_part_3_716\tबिस्वास लोड गर्नुहोस्\n',
#  'ku_hackfest_part_3_717\tअन गर्ने क्षमता तपाईंको सबैभन्दा ठूलो शक्ति\n',
#  'ku_hackfest_part_3_718\tखुशीले प्रचुरता लाइसन गर्नुहोस्\n',
#  'ku_hackfest_part_3_719\t5\n',
#  'ku_hackfest_part_3_720\tअरूको सुझावको कोठामा तपाईंलाई चोट पुर्याउने कुनै शक्ति छैन\n',
#  'ku_hackfest_part_3_721\tव्यक्तित्वको आफ्नो विचार मात्र छ\n',
#  'ku_hackfest_part_3_722\tतपाईं\n',
#  'ku_hackfest_part_3_723\tअरूको विचार वा सुझावलाई अस्वीकृत गर्न छन् गर्नसक्नुहुन्छ\n',
#  'ku_hackfest_part_3_724\tनराम्रो विचारलाई\n',
#  'ku_hackfest_part_3_725\tदृढ भएर भन्न सक्नुहुन्छ\n',
#  'ku_hackfest_part_3_726\tफैशनको यो छनोट गर्ने शक्ति saki\n',
#  'ku_hackfest_part_3_727\tभए कस्तो प्रतिक्रिया गर्नुहुन्छ\n',
#  'ku_hackfest_part_3_729\tहास्न शब्दमा ध्यान छैन\n',
#  'ku_hackfest_part_3_730\tभनि हरेक शब्दको हिसाब दिनुपर्नेछ\n',
#  'ku_hackfest_part_3_731\tफैलियो नभन्नुस्\n',
#  'ku_hackfest_part_3_732\tMasu फल हुनेछ\n',
#  'ku_hackfest_part_3_733\tनिर्मलपोखरी छुटेछ\n',
#  'ku_hackfest_part_3_734\tMabharat in ausadi\n',
#  'ku_hackfest_part_3_735\tभएको हो फिल्म ब\n',
#  'ku_hackfest_part_3_736\tभत्ता बुझ्न सक्दैन\n',
#  'ku_hackfest_part_3_737\tUs ta क्षेत्रलाई\n',
#  'ku_hackfest_part_3_738\tवास्तविकतामा\n',
#  'ku_hackfest_part_3_739\tबदलि दिनेछ\n',
#  'ku_hackfest_part_3_740\t7\n',
#  'ku_hackfest_part_3_741\tभएको मस्तिष्क नराम्रो छैन\n',
#  'ku_hackfest_part_3_742\tप्रकृतिको कुनै पनि सक्दैन राम्रो हुँदैन\n',
#  'ku_hackfest_part_3_743\tतपाईं प्रकृतिको शब्दलाई कसरी प्रयोग गर्नुहुन्छ त्यसमा निर्भर हुन्छ\n',
#  'ku_hackfest_part_3_744\tआफ्नो मस्तिष्कको प्रयोग\n',
#  'ku_hackfest_part_3_745\tहरित ठाउँ म सबै मानिसलाई बरदान दिन उपचार गर्न र प्रेरित गर्नको निमित्त\n',
#  'ku_hackfest_part_3_746\tR\n',
#  'ku_hackfest_part_3_747\tगइयो नभन्नुहोस्\n',
#  'ku_hackfest_part_3_748\tम गर्न सक्दिन\n',
#  'ku_hackfest_part_3_749\tIs bhakyachhu ठाउँमा अगाडि दिएको बाक्य राखेर\n',
#  'ku_hackfest_part_3_750\tयस डरबाट बस्नुस्\n',
#  'ku_hackfest_part_3_751\tम आफ्नो अवस्थित on मनको शक्तिले\n',
#  'ku_hackfest_part_3_752\tसारा काम गर्नसक्छ\n',
#  'ku_hackfest_part_3_753\t9\n',
#  'ku_hackfest_part_3_754\tJhor\n',
#  'ku_hackfest_part_3_755\tअज्ञान भ्रम र विश्वास हुन्न बाहेक\n',
#  'ku_hackfest_part_3_756\tSaasho सत्य र जीवनको सिद्धान्तको दृष्टिकोणले\n',
#  'ku_hackfest_part_3_757\tSamjhna सुरु गर्नुहोस्\n',
#  'ku_hackfest_part_3_758\tअरुलाई आफ्नो लागि सोच्न अनुमति नदिनुस्\n',
#  'ku_hackfest_part_3_759\tआफ्नो विशाल\n',
#  'ku_hackfest_part_3_760\tGamchha moss\n',
#  'ku_hackfest_part_3_761\tर आफ्नो नि\n',
#  'ku_hackfest_part_3_762\tआफ्नी लिनुहोस्\n',
#  'ku_hackfest_part_3_763\t10\n',
#  'ku_hackfest_part_3_764\tमहिला आफ्नो हातमा\n',
#  'ku_hackfest_part_3_765\tAvashyak मनको कप्तान हुनुहुन्छ\n',
#  'ku_hackfest_part_3_766\tराख्नु भागेको मालिक हुनुहुन्छ\n',
#  'ku_hackfest_part_3_767\tयाद राख्नुस्\n',
#  'ku_hackfest_part_3_768\tअनिशको छनोट गर्न सक्ने क्षमता छ\n',
#  'ku_hackfest_part_3_769\tजिन्दगी rose\n',
#  'ku_hackfest_part_3_770\tRamro जनस्वास्थ्य rose\n',
#  'ku_hackfest_part_3_771\tर खुशी हुनु\n',
#  'ku_hackfest_part_3_772\tघार\n']

# %%
with open("part3_sort.txt", "w") as f:
    for line in lines:
        f.write(line)

# %%
# !head -n 10 part3.txt
# Out:
# ku_hackfest_part_3_345	2013 आफ्नो विश्वासिलो शान्त छ
# ku_hackfest_part_3_250	नियन्त्रित र विशिष्ट घेरामा
# ku_hackfest_part_3_332	आफ्नो सुझावका कारण भएको थियो
# ku_hackfest_part_3_196	चेतन मन
# ku_hackfest_part_3_350	एक हप्ता kavyaschool पिउने पूर्ण विश्वस्त liscen थिइन्
# ku_hackfest_part_3_177	Movie साडी एवं विश्वासको नौलो प्रणाली सृजना गर्ने गरी बारम्बार सकारात्मक र प्रगतिशील भाव ल्याउने
# ku_hackfest_part_3_517	बेवास्ता गर्न सक्थे
# ku_hackfest_part_3_610	सर्वोच्च तनमन मार्फत दादा ruaaune बेला सुस्ती अघि सार्नु हुन्छ
# ku_hackfest_part_3_468	Himadri अधिकांश परशुराम हरूको उद्देश्य तपाईंलाई अरुले छाया लोप हुनुको फाइदा हरु को
# ku_hackfest_part_3_268	मिलिजुली निको भएमा
